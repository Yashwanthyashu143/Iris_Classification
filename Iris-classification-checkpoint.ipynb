# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['Class'].value_counts()
# Out:
# Class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df['SepalLength'].hist()
# Out:
# <AxesSubplot:>

# %%
df['SepalWidth'].hist()
# Out:
# <AxesSubplot:>

# %%
df['PetalLength'].hist()
# Out:
# <AxesSubplot:>

# %%
df['PetalWidth'].hist()
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Class
# 0          5.1         3.5          1.4         0.2      0
# 1          4.9         3.0          1.4         0.2      0
# 2          4.7         3.2          1.3         0.2      0
# 3          4.6         3.1          1.5         0.2      0
# 4          5.0         3.6          1.4         0.2      0

# %%
df.corr()
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth     Class
# SepalLength     1.000000   -0.109369     0.871754    0.817954  0.782561
# SepalWidth     -0.109369    1.000000    -0.420516   -0.356544 -0.419446
# PetalLength     0.871754   -0.420516     1.000000    0.962757  0.949043
# PetalWidth      0.817954   -0.356544     0.962757    1.000000  0.956464
# Class           0.782561   -0.419446     0.949043    0.956464  1.000000

# %%
corr = df.corr()
sns.heatmap(corr, annot = True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns='Class')
y = df['Class']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\YASHWANTH\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy: ", model.score(x_test,y_test)*100)
# Out:
# Accuracy:  97.77777777777777

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier()
model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ", model2.score(x_test,y_test)*100)
# Out:
# Accuracy:  93.33333333333333

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN 

knn = KNN(n_neighbors=3) 
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(x_test,y_test) * 100
# Out:
# 97.77777777777777

# %%
arr = knn.predict([[7.6,3,6.6,2.0],
                     [6.7,3.1,4.4,1.4]])
for i in arr:
    if i == 0:
        print('Iris Setosa')
    elif i == 1:
        print('Iris Versicolour')
    else:
        print('Iris Virginica')
# Out:
# Iris Virginica
# Iris Versicolour
# C:\Users\YASHWANTH\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
 
from joblib import Parallel, delayed 
import joblib 
  
  
# Save the model as a pickle in a file 
joblib.dump(knn, 'filename.pkl')
# Out:
# ['filename.pkl']

# %%
le.inverse_transform([0, 1, 2])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)
